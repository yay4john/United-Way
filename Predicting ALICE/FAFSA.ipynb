# %% [markdown]
# # Predicting ALICE
#
# Last Edited: Mar 2024 \
# Edited By: John Cox
#
# ### Goal
# Collate several data sources, including FAFSA completion, high school graduation, and kindergarten readiness, and use them to predict ALICE rates.
#
# ### Data sources & descriptions
# High school graduation: https://data.wa.gov \
# FAFSA completion: https://studentaid.gov/data-center/student/application-volume/fafsa-completion-high-school \
# Kindergarten readiness: https://ospi.k12.wa.us/data-reporting/data-portal?title=readiness&field_years1_target_id=All&field_data_domain_target_id=All&field_level_of_aggregation_target_id=All&field_grade_span_target_id=All \
# ALICE: https://www.unitedforalice.org/washington

# %% [markdown]
# ## FAFSA Completion Rates
# First, we load in the FAFSA data

# %%
# import packages
import pandas as pd
import glob

# %%
# get all the fafsa files in the folder
f_all_files = glob.glob('FAFSA raw/*.csv')

f_li = []

# unpack the list of files
for filename in f_all_files:
    f_df = pd.read_csv(filename, index_col=None, header=0, dtype = {'School Code' : str, 'Name' : str, 'City' : str, 
                                                   'State' : str, 'Submitted' : str, 'Completed' : str, 
                                                   'Cycle' : str}
                        , parse_dates=[7])
    f_li.append(f_df)

# put the files all together into one df
fafsa_raw = pd.concat(f_li, axis=0, ignore_index=True)
fafsa_raw.head()
# Out:
#   School Code                          Name       City State Submitted  \
# 0         NaN               AKIACHAK SCHOOL   AKIACHAK    AK        <5
# 1         NaN  ALASKA MIDDLE COLLEGE SCHOOL  ANCHORAGE    AK         5
# 2         NaN   ANCHORAGE CHRISTIAN SCHOOLS  ANCHORAGE    AK        15
# 3         NaN            BARROW HIGH SCHOOL     BARROW    AK        12
# 4         NaN          BARTLETT HIGH SCHOOL  ANCHORAGE    AK        41
#
#   Completed      Cycle As of Date
# 0        <5  2022/2023 2022-03-31
# 1         5  2022/2023 2022-03-31
# 2        14  2022/2023 2022-03-31
# 3        11  2022/2023 2022-03-31
# 4        37  2022/2023 2022-03-31

# %%
fafsa_with_codes = fafsa_raw[['Cycle','As of Date','Name','City','State','Submitted',
                                     'Completed']].sort_values(by = ['As of Date','State','City','Name']
                                                               , ascending = True)
fafsa_with_codes
# Out:
#              Cycle As of Date                           Name       City State  \
# 163679   2016/2017 2016-01-31                AKIACHAK SCHOOL   AKIACHAK    AK
# 163680   2016/2017 2016-01-31                ALAKANUK SCHOOL   ALAKANUK    AK
# 163682   2016/2017 2016-01-31  ALASKA MILITARY YOUTH ACADEMY  ANCHORAGE    AK
# 163683   2016/2017 2016-01-31    ANCHORAGE CHRISTIAN SCHOOLS  ANCHORAGE    AK
# 163685   2016/2017 2016-01-31                   AVAIL SCHOOL  ANCHORAGE    AK
# ...            ...        ...                            ...        ...   ...
# 2582874  2023/2024 2023-12-31              UPTON HIGH SCHOOL      UPTON    WY
# 2582876  2023/2024 2023-12-31          WHEATLAND HIGH SCHOOL  WHEATLAND    WY
# 2582880  2023/2024 2023-12-31            WORLAND HIGH SCHOOL    WORLAND    WY
# 2582881  2023/2024 2023-12-31   WRIGHT JR. & SR. HIGH SCHOOL     WRIGHT    WY
# 2582867  2023/2024 2023-12-31          SOUTHEAST HIGH SCHOOL      YODER    WY
#
#         Submitted Completed
# 163679         <5        <5
# 163680         <5        <5
# 163682         <5        <5
# 163683          7         5
# 163685         <5        <5
# ...           ...       ...
# 2582874         8         7
# 2582876        37        37
# 2582880        64        63
# 2582881        14        13
# 2582867        10        10
#
# [2639055 rows x 7 columns]

# %% [markdown]
# Next cleanup: Submitted and Completed. We'll remove anything with '<5' in either column, putting a floor on school size in consideration. We'll also reduce to just WA. Then we'll update column types to ensure the numbers are numeric.
#
# The <5 filter removes about 160k rows.

# %%
fafsa_clean = fafsa_with_codes[(fafsa_with_codes['Submitted'] != '<5') & (fafsa_with_codes['Completed'] != '<5')]

fafsa_wa = fafsa_clean[fafsa_clean['State'] == 'WA']

fafsa_wa['SchoolYear'] = fafsa_wa['Cycle'].str.slice(5,9)

fafsa_data = fafsa_wa.astype({'Submitted': int, 'Completed': int})
# Out:
# /var/folders/13/tb353hv16bg0qsrdngc6r2v40000gn/T/ipykernel_56016/3170210233.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fafsa_wa['SchoolYear'] = fafsa_wa['Cycle'].str.slice(5,9)

# %% [markdown]
# Let's add county to everything.

# %%
county = pd.read_csv('Counties.csv')
county['CITY NAME'] = county['CITY NAME'].str.upper()

fafsa_county = fafsa_data.merge(county, left_on = 'City', right_on = 'CITY NAME')

fafsa = fafsa_county[['SchoolYear','As of Date','Name','COUNTY NAME','Submitted','Completed']]
fafsa
# Out:
#       SchoolYear As of Date                          Name   COUNTY NAME  \
# 0           2017 2016-01-31    J M WEATHERWAX HIGH SCHOOL  Grays Harbor
# 1           2017 2016-02-29    J M WEATHERWAX HIGH SCHOOL  Grays Harbor
# 2           2017 2016-03-31            HARBOR HIGH SCHOOL  Grays Harbor
# 3           2017 2016-03-31    J M WEATHERWAX HIGH SCHOOL  Grays Harbor
# 4           2017 2016-04-30            HARBOR HIGH SCHOOL  Grays Harbor
# ...          ...        ...                           ...           ...
# 47450       2024 2023-08-31  PACIFIC CREST ONLINE ACADEMY        Benton
# 47451       2024 2023-09-30  PACIFIC CREST ONLINE ACADEMY        Benton
# 47452       2024 2023-10-31  PACIFIC CREST ONLINE ACADEMY        Benton
# 47453       2024 2023-11-30  PACIFIC CREST ONLINE ACADEMY        Benton
# 47454       2024 2023-12-31  PACIFIC CREST ONLINE ACADEMY        Benton
#
#        Submitted  Completed
# 0             26         19
# 1             39         33
# 2              6          5
# 3             57         47
# 4              7          6
# ...          ...        ...
# 47450          9          6
# 47451          9          7
# 47452          9          7
# 47453          9          7
# 47454         10          7
#
# [47455 rows x 6 columns]

# %%
#fafsa[(fafsa['COUNTY NAME'] == 'Thurston') & (fafsa['SchoolYear'] == '2023') & (fafsa['As of Date'] == '2022-12-31')]

# %% [markdown]
# ## Graduation Rates
# Now pull in graduation data. This data hasn't been combined yet, so we'll do that here.

# %%
# get all the grad files in the folder
all_files = glob.glob('Graduation raw/*.csv')

li = []

# unpack the list of files
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, dtype = object)
    li.append(df)

# put the files all together into one df
grad_raw = pd.concat(li, axis=0, ignore_index=True)
grad_raw.head()
# Out:
#   SchoolYear OrganizationLevel        County                 ESDName  \
# 0       2023            School  Grays Harbor  Capital Region ESD 113
# 1       2023            School  Grays Harbor  Capital Region ESD 113
# 2       2023            School  Grays Harbor  Capital Region ESD 113
# 3       2023            School  Grays Harbor  Capital Region ESD 113
# 4       2023            School  Grays Harbor  Capital Region ESD 113
#
#   ESDOrganizationId DistrictCode              DistrictName  \
# 0            100004        14005  Aberdeen School District
# 1            100004        14005  Aberdeen School District
# 2            100004        14005  Aberdeen School District
# 3            100004        14005  Aberdeen School District
# 4            100004        14005  Aberdeen School District
#
#   DistrictOrganizationId SchoolCode            SchoolName  ... Year6Dropout  \
# 0                 100010       5514  Grays Harbor Academy  ...          NaN
# 1                 100010       5514  Grays Harbor Academy  ...          NaN
# 2                 100010       5514  Grays Harbor Academy  ...          NaN
# 3                 100010       5514  Grays Harbor Academy  ...          NaN
# 4                 100010       5514  Grays Harbor Academy  ...          NaN
#
#   Year7Dropout TransferOut FinalCohort Graduate Continuing Dropout  \
# 0          NaN         NaN         NaN      NaN        NaN     NaN
# 1          NaN         NaN         NaN      NaN        NaN     NaN
# 2          NaN         NaN         NaN      NaN        NaN     NaN
# 3          NaN         NaN         NaN      NaN        NaN     NaN
# 4          NaN         NaN         NaN      NaN        NaN     NaN
#
#   GraduationRate                DataAsOf CurrentSchoolType
# 0            NaN  12/11/2023 12:00:00 AM               NaN
# 1            NaN  12/11/2023 12:00:00 AM               NaN
# 2            NaN  12/11/2023 12:00:00 AM               NaN
# 3            NaN  12/11/2023 12:00:00 AM               NaN
# 4            NaN  12/11/2023 12:00:00 AM               NaN
#
# [5 rows x 32 columns]

# %%
# Filter the data to just school level data for all students
grad_filter1 = grad_raw[(grad_raw['OrganizationLevel'] == 'School') & (grad_raw['StudentGroupType'] == 'All')]

# We also filter out the records with surpressed data. This is a known limitation: small groups
# or groups that could possibly be traced are filtered out upstream in the data.
# Possible workaround: aggregate to district level

grad_filter2 = grad_filter1[(grad_filter1['Suppression'] == 'No Suppression') 
                            | (grad_filter1['Suppression'] == 'No DAT')]

# Finally, filter to just the 4-year cohort. If we had complete data, we would do a rolling calculation
# to include 'super seniors' in the graduation count each year... but with suppressed data, this is asking for 
# trouble

grad_filter3 = grad_filter2[grad_filter2['Cohort'] == 'Four Year']

# Pick the relevent columns

grad = grad_filter3[['SchoolYear','County','DistrictName','SchoolName','FinalCohort','Graduate']]
grad['SchoolName'] = grad['SchoolName'].str.upper()
grad
# Out:
# /var/folders/13/tb353hv16bg0qsrdngc6r2v40000gn/T/ipykernel_56016/984140451.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grad['SchoolName'] = grad['SchoolName'].str.upper()
#        SchoolYear        County               DistrictName  \
# 74           2023  Grays Harbor   Aberdeen School District
# 224          2023  Grays Harbor   Aberdeen School District
# 394          2023        Skagit  Anacortes School District
# 483          2023        Skagit  Anacortes School District
# 612          2023     Snohomish  Arlington School District
# ...           ...           ...                        ...
# 680021       2017        Yakima     Yakima School District
# 680184       2017        Yakima     Yakima School District
# 680332       2017      Thurston       Yelm School District
# 680413       2017      Thurston       Yelm School District
# 680568       2017        Yakima     Zillah School District
#
#                                    SchoolName FinalCohort Graduate
# 74           HARBOR JUNIOR/SENIOR HIGH SCHOOL          26       20
# 224                J M WEATHERWAX HIGH SCHOOL         191      154
# 394                     ANACORTES HIGH SCHOOL         180      173
# 483                     CAP SANTE HIGH SCHOOL          38       28
# 612                     ARLINGTON HIGH SCHOOL         399      364
# ...                                       ...         ...      ...
# 680021                          YAKIMA ONLINE          37       17
# 680184  YAKIMA SATELLITE ALTERNATIVE PROGRAMS          22        3
# 680332                  YELM EXTENSION SCHOOL          67       17
# 680413                    YELM HIGH SCHOOL 12         369      320
# 680568                     ZILLAH HIGH SCHOOL         109      103
#
# [3885 rows x 6 columns]

# %% [markdown]
# We'll be joining based on school name, county, and school year.

# %%
joined = fafsa.merge(grad, left_on = ['SchoolYear','Name','COUNTY NAME'], right_on = ['SchoolYear','SchoolName','County'])
output = joined[['SchoolYear','As of Date','Name','DistrictName','County','FinalCohort','Graduate','Submitted','Completed']]
output
# Out:
#       SchoolYear As of Date                        Name  \
# 0           2017 2016-01-31  J M WEATHERWAX HIGH SCHOOL
# 1           2017 2016-02-29  J M WEATHERWAX HIGH SCHOOL
# 2           2017 2016-03-31  J M WEATHERWAX HIGH SCHOOL
# 3           2017 2016-04-30  J M WEATHERWAX HIGH SCHOOL
# 4           2017 2016-05-31  J M WEATHERWAX HIGH SCHOOL
# ...          ...        ...                         ...
# 25671       2022 2021-08-31           TWO RIVERS SCHOOL
# 25672       2022 2021-09-30           TWO RIVERS SCHOOL
# 25673       2022 2021-10-31           TWO RIVERS SCHOOL
# 25674       2022 2021-11-30           TWO RIVERS SCHOOL
# 25675       2022 2021-12-31           TWO RIVERS SCHOOL
#
#                             DistrictName        County FinalCohort Graduate  \
# 0               Aberdeen School District  Grays Harbor         192      162
# 1               Aberdeen School District  Grays Harbor         192      162
# 2               Aberdeen School District  Grays Harbor         192      162
# 3               Aberdeen School District  Grays Harbor         192      162
# 4               Aberdeen School District  Grays Harbor         192      162
# ...                                  ...           ...         ...      ...
# 25671  Snoqualmie Valley School District          King          11        9
# 25672  Snoqualmie Valley School District          King          11        9
# 25673  Snoqualmie Valley School District          King          11        9
# 25674  Snoqualmie Valley School District          King          11        9
# 25675  Snoqualmie Valley School District          King          11        9
#
#        Submitted  Completed
# 0             26         19
# 1             39         33
# 2             57         47
# 3             66         57
# 4             70         65
# ...          ...        ...
# 25671          7          5
# 25672          7          5
# 25673          8          6
# 25674          8          6
# 25675          8          6
#
# [25676 rows x 9 columns]

# %%
output.to_csv('FAFSA Graduation Data.csv')

# %% [markdown]
# ## Kindergarten Readiness

# %%
# get all the grad files in the folder
all_files = glob.glob('Kindergarten Readiness/*.csv')

li = []

# unpack the list of files
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, dtype = object)
    li.append(df)

# put the files all together into one df
kind_raw = pd.concat(li, axis=0, ignore_index=True)
kind_raw.head()
# Out:
#   schoolyear OrganizationLevel OrganizationId WashingtonStateCode  \
# 0    2014-15          District         100010              103300
# 1    2014-15          District         100010              103300
# 2    2014-15          District         100010              103300
# 3    2014-15          District         100010              103300
# 4    2014-15          District         100010              103300
#
#   washingtonstatename ESDOrganizationId                 ESDName  \
# 0         State Total            100004  Capital Region ESD 113
# 1         State Total            100004  Capital Region ESD 113
# 2         State Total            100004  Capital Region ESD 113
# 3         State Total            100004  Capital Region ESD 113
# 4         State Total            100004  Capital Region ESD 113
#
#   DistrictOrganizationId              DistrictName SchoolOrganizationId  ...  \
# 0                 100010  Aberdeen School District                  NaN  ...
# 1                 100010  Aberdeen School District                  NaN  ...
# 2                 100010  Aberdeen School District                  NaN  ...
# 3                 100010  Aberdeen School District                  NaN  ...
# 4                 100010  Aberdeen School District                  NaN  ...
#
#   StudentGroup    Domain                Measure MeasureValue Numerator  \
# 0        Asian      Math      MathReadinessFlag            Y       NaN
# 1   Low-Income      Math      MathReadinessFlag            Y       120
# 2         Male      Math   MathDevelopmentLevel  3-year olds        26
# 3         Male      Math   MathDevelopmentLevel  4-year olds        51
# 4       Female  Physical  PhysicalReadinessFlag            N         8
#
#   Denominator  Percent DevelopmentLevel Suppress DataAsOf
# 0         NaN      NaN              NaN      NaN      NaN
# 1         191  0.62827              NaN      NaN      NaN
# 2         138  0.18841              NaN      NaN      NaN
# 3         138  0.36957              NaN      NaN      NaN
# 4         122  0.06557              NaN      NaN      NaN
#
# [5 rows x 22 columns]

# %%
# Filter the data to just school level data for all students
kind_filter1 = kind_raw[(kind_raw['OrganizationLevel'] == 'School') & (kind_raw['StudentGroupType'] == 'All')]

kind_filter2 = kind_filter1[(kind_filter1['Measure'] == 'NumberofDomainsReadyforKindergarten') & (kind_filter1['MeasureValue'] == '6')]

# Pick the relevent columns
# Pick the relevent columns

kind = kind_filter2[['schoolyear','DistrictName','SchoolName','Percent']]
kind['SchoolName'] = kind['SchoolName'].str.upper()
kind
# Out:
# /var/folders/13/tb353hv16bg0qsrdngc6r2v40000gn/T/ipykernel_56016/2592029662.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kind['SchoolName'] = kind['SchoolName'].str.upper()
#         schoolyear                   DistrictName  \
# 102217     2014-15        Othello School District
# 102738     2014-15        Othello School District
# 103817     2014-15           Lind School District
# 104093     2014-15      Clarkston School District
# 104609     2014-15      Clarkston School District
# ...            ...                            ...
# 7322890    2015-16  SOAR Academy Charter District
# 7323075    2015-16    Clover Park School District
# 7323727    2015-16          Pasco School District
# 7324380    2015-16          Pasco School District
# 7324939    2015-16       Richland School District
#
#                                                 SchoolName  Percent
# 102217                                 LUTACAGA ELEMENTARY  0.05376
# 102738                          HIAWATHA ELEMENTARY SCHOOL  0.32558
# 103817                              LIND ELEMENTARY SCHOOL  0.92857
# 104093                                  PARKWAY ELEMENTARY  0.42553
# 104609                                 GRANTHAM ELEMENTARY   0.2439
# ...                                                    ...      ...
# 7322890  SOAR ACADEMY (CLOSED AFTER 2018-2019 SCHOOL YEAR)  0.92857
# 7323075                             FOUR HEROES ELEMENTARY  0.42697
# 7323727                 BARBARA MCCLINTOCK STEM ELEMENTARY  0.38095
# 7324380                       CAPTAIN GRAY STEM ELEMENTARY  0.05263
# 7324939                                 ORCHARD ELEMENTARY  0.71429
#
# [10260 rows x 4 columns]

# %%
# get unique list of districts and counties

dlist = output[['DistrictName','County']].drop_duplicates()
dlist
# Out:
#                          DistrictName        County
# 0            Aberdeen School District  Grays Harbor
# 122         Anacortes School District        Skagit
# 231         Arlington School District     Snohomish
# 243          Lakewood School District     Snohomish
# 414    Asotin-Anatone School District        Asotin
# ...                               ...           ...
# 25389          Morton School District         Lewis
# 25458       Mossyrock School District         Lewis
# 25504           Tekoa School District       Whitman
# 25550        Oakville School District  Grays Harbor
# 25576          Valley School District       Stevens
#
# [221 rows x 2 columns]

# %%
kind_joined = kind.merge(dlist, left_on = ['DistrictName'], right_on = ['DistrictName'], how = 'left')
kind_output = kind_joined[['schoolyear','County','DistrictName','SchoolName','Percent']]
kind_output
# Out:
#       schoolyear    County                   DistrictName  \
# 0        2014-15     Adams        Othello School District
# 1        2014-15     Adams        Othello School District
# 2        2014-15     Adams           Lind School District
# 3        2014-15    Asotin      Clarkston School District
# 4        2014-15    Asotin      Clarkston School District
# ...          ...       ...                            ...
# 10255    2015-16       NaN  SOAR Academy Charter District
# 10256    2015-16    Pierce    Clover Park School District
# 10257    2015-16  Franklin          Pasco School District
# 10258    2015-16  Franklin          Pasco School District
# 10259    2015-16    Benton       Richland School District
#
#                                               SchoolName  Percent
# 0                                    LUTACAGA ELEMENTARY  0.05376
# 1                             HIAWATHA ELEMENTARY SCHOOL  0.32558
# 2                                 LIND ELEMENTARY SCHOOL  0.92857
# 3                                     PARKWAY ELEMENTARY  0.42553
# 4                                    GRANTHAM ELEMENTARY   0.2439
# ...                                                  ...      ...
# 10255  SOAR ACADEMY (CLOSED AFTER 2018-2019 SCHOOL YEAR)  0.92857
# 10256                             FOUR HEROES ELEMENTARY  0.42697
# 10257                 BARBARA MCCLINTOCK STEM ELEMENTARY  0.38095
# 10258                       CAPTAIN GRAY STEM ELEMENTARY  0.05263
# 10259                                 ORCHARD ELEMENTARY  0.71429
#
# [10260 rows x 5 columns]

# %%
kind_output.to_csv('Kindergarten.csv')

# %% [markdown]
# ## ALICE

# %%
alice_raw = pd.read_excel('ALICE/DataSheet_WA.xlsx', sheet_name = 'County')
alice_raw.head()
# Out:
#    Year  GEO.id2         GEO.display_label County       State State Abbr  \
# 0  2010    53001  Adams County, Washington  Adams  Washington         WA
# 1  2012    53001  Adams County, Washington  Adams  Washington         WA
# 2  2014    53001  Adams County, Washington  Adams  Washington         WA
# 3  2016    53001  Adams County, Washington  Adams  Washington         WA
# 4  2018    53001  Adams County, Washington  Adams  Washington         WA
#
#    Households  Poverty Households  ALICE Households  Above ALICE Households  \
# 0        5599                1044              1504                    3051
# 1        5722                1117              1806                    2799
# 2        5827                1166              1833                    2828
# 3        5733                1076              1722                    2935
# 4        5881                1135              1733                    3013
#
#    ALICE Threshold - HH under 65  ALICE Threshold - HH 65 years and over  \
# 0                          40000                                   30000
# 1                          45000                                   30000
# 2                          50000                                   30000
# 3                          50000                                   35000
# 4                          50000                                   40000
#
#   Source: American Community Survey
# 0                             5-Year
# 1                             5-Year
# 2                             5-Year
# 3                             5-Year
# 4                             5-Year

# %%
# Pick the relevent columns

alice = alice_raw[['Year','County','Households','Poverty Households','ALICE Households']]
alice
# Out:
#      Year  County  Households  Poverty Households  ALICE Households
# 0    2010   Adams        5599                1044              1504
# 1    2012   Adams        5722                1117              1806
# 2    2014   Adams        5827                1166              1833
# 3    2016   Adams        5733                1076              1722
# 4    2018   Adams        5881                1135              1733
# ..    ...     ...         ...                 ...               ...
# 268  2014  Yakima       79700               14271             22649
# 269  2016  Yakima       81084               12279             25681
# 270  2018  Yakima       83320               12963             24844
# 271  2019  Yakima       83992               12400             23232
# 272  2021  Yakima       86992               11391             28309
#
# [273 rows x 5 columns]

# %%
alice.to_csv('ALICE.csv')
